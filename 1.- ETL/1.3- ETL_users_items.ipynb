# %% [markdown]
#  # ETL de **"users_items"**
#  -------------

# %% [markdown]
# En este jupyter notebook se desarrolla la extracción, transformación y carga del conjunto del dataset `"user_items"`

# %% [markdown]
# -------------
# ### Tabla de contenido
#
# - 1.- Introducción
# - 2.- Importación de las librerías y funciones personalizadas para el ETL
#     - 2.1.- Librerías
#     - 2.2.- Funciones Personalizadas
# - 3.- Desarrollo del proceso de ETL
#     - 3.1.- Extracción de datos
#         - 3.1.1.- Carga de archivos "user_items.json.gz"
#     - 3.2.- Transformación de datos
#         - 3.2.1.- Aspectos generales del Dataframe
#         - 3.2.2.- Exploración y tratamiendo de datos vacíos
#         - 3.2.3.- Eliminación de datos duplicados
#         - 3.2.4.- Datos incorrectos o irrelevantes
#         - 3.2.5.- Datos categóricos
#     - 3.3.- Carga de Datos
#         - 3.3.1 Generación del archivo limpio
# -------------

# %% [markdown]
# ## **<span style="color: #d8572a;">1.- Introducción</span>**

# %% [markdown]
# Este trabajo ETL tiene como objetivo procesar e integrar un conjunto de datos que contiene información sobre videojuegos de Steam. El conjunto de datos, titulado "user_items", consta de 88310 filas y 5 columnas, luego de un proceso de limpieza exhaustivo para eliminar filas con valores NaN. Los datos extraídos se transformarán y cargarán en un sistema de destino para su posterior análisis y utilización.

# %% [markdown]
# ## **<span style="color: #d8572a;">2.- Importación de las librerías y funciones personalizadas para el ETL</span>**

# %% [markdown]
# ### **<span style="color: #f7b538;">2.1.- Librerías</span>**

# %%
import pandas as pd
import numpy as np
import ast
import gzip

# %% [markdown]
# ### **<span style="color: #f7b538;">2.2.- Funciones Personalizadas</span>**

# %%
import Func_personalizadas.FPersonalizadas as FP

# %% [markdown]
# ## **<span style="color: #d8572a;">3.- Desarrollo del proceso de ETL</span>**

# %% [markdown]
# ### **<span style="color: #f7b538;">3.1.- Extracción de datos</span>**

# %% [markdown]
# #### 3.1.1.- Carga de archivos "user_items.json.gz"

# %%
ruta_archivo= r"C:\Users\USUARIO\OneDrive\6.- Data Science\1.- Experiencia Soy Henry Bootcamp\Labs\PI 1\ML_DevOps_Steam_Project\Datasets\users_items.json.gz"

# %%
# Definimos una lista vacia
rows = []

# Abrimos gzip-compressed JSON file
with gzip.open(ruta_archivo, 'rb') as f:
    #   Iteramos sobre cada línea en el archivo
    for line in f.readlines():
        #  Decodificamos la línea y la evaluamos como un literal de Python
        rows.append(ast.literal_eval(line.decode('utf-8')))
        
# Convertimos la lista de diccionarios en un DataFrame
df_users_items=pd.DataFrame(rows)

# %% [markdown]
# ### **<span style="color: #f7b538;">**3.2.- Transformación de datos**</span>**

# %% [markdown]
# #### 3.2.1.- Aspectos generales del Dataframe

# %%
# Dimensiones del dataframe
df_users_items.shape
# Out:
# (88310, 5)

# %%
df_users_items.columns
# Out:
# Index(['user_id', 'items_count', 'steam_id', 'user_url', 'items'], dtype='object')

# %%
df_users_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88310 entries, 0 to 88309
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      88310 non-null  object
#  1   items_count  88310 non-null  int64
#  2   steam_id     88310 non-null  object
#  3   user_url     88310 non-null  object
#  4   items        88310 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB

# %%
df_users_items.user_id.value_counts()
# Out:
# user_id
# X03-Suits            3
# 76561198027488037    3
# 76561198100326818    3
# 76561198309337430    3
# 76561198051777058    3
#                     ..
# 8392158              1
# 76561198056804863    1
# SparklezTheTurtle    1
# 76561198019707497    1
# edward_tremethick    1
# Name: count, Length: 87626, dtype: int64

# %% [markdown]
# ### 3.2.2.- Exploración y tratamiendo de datos vacíos

# %% [markdown]
# Eliminamos todas las filas que contengan datos vacíos en todos los campos

# %%
## Eliminamos las filas vacías
df_users_items = df_users_items.dropna(how='all').reset_index(drop=True)
## Evaluamos dimensiones
df_users_items.shape
# Out:
# (88310, 5)

# %% [markdown]
# Revisamos los tipos de datos y los nulos por cada columna

# %%
FP.tabla_tipo_datos(df_users_items)
# Out:
#   nombre_campo        tipo_datos  no_nulos_%  nulos_%  nulos
# 0      user_id   [<class 'str'>]       100.0      0.0      0
# 1  items_count   [<class 'int'>]       100.0      0.0      0
# 2     steam_id   [<class 'str'>]       100.0      0.0      0
# 3     user_url   [<class 'str'>]       100.0      0.0      0
# 4        items  [<class 'list'>]       100.0      0.0      0

# %% [markdown]
# Revisamos a detalles las columnas que tienen estructura tipo lista, para entender su estructura

# %%
col_tipo_list = FP.identificar_columnas_con_listas(df_users_items)

# %%
for col in col_tipo_list:    
    print(f"Columna {col} \n Tipo de Dato: ",df_users_items[col][5])
# Out:
# Columna items
#  Tipo de Dato:  [{'item_id': '50', 'item_name': 'Half-Life: Opposing Force', 'playtime_forever': 256, 'playtime_2weeks': 0}, {'item_id': '240', 'item_name': 'Counter-Strike: Source', 'playtime_forever': 167, 'playtime_2weeks': 0}, {'item_id': '320', 'item_name': 'Half-Life 2: Deathmatch', 'playtime_forever': 3674, 'playtime_2weeks': 0}, {'item_id': '4000', 'item_name': "Garry's Mod", 'playtime_forever': 358, 'playtime_2weeks': 0}, {'item_id': '6570', 'item_name': 'Onimusha 3: Demon Siege', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '220', 'item_name': 'Half-Life 2', 'playtime_forever': 1299, 'playtime_2weeks': 0}, {'item_id': '340', 'item_name': 'Half-Life 2: Lost Coast', 'playtime_forever': 29, 'playtime_2weeks': 0}, {'item_id': '360', 'item_name': 'Half-Life Deathmatch: Source', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '380', 'item_name': 'Half-Life 2: Episode One', 'playtime_forever': 170, 'playtime_2weeks': 0}, {'item_id': '400', 'item_name': 'Portal', 'playtime_forever': 275, 'playtime_2weeks': 0}, {'item_id': '420', 'item_name': 'Half-Life 2: Episode Two', 'playtime_forever': 544, 'playtime_2weeks': 0}, {'item_id': '12900', 'item_name': 'Audiosurf', 'playtime_forever': 95, 'playtime_2weeks': 0}, {'item_id': '13240', 'item_name': 'Unreal Tournament: Game of the Year Edition', 'playtime_forever': 110, 'playtime_2weeks': 0}, {'item_id': '13230', 'item_name': 'Unreal Tournament 2004', 'playtime_forever': 1668, 'playtime_2weeks': 0}, {'item_id': '15700', 'item_name': "Oddworld: Abe's Oddysee", 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '15710', 'item_name': "Oddworld: Abe's Exoddus", 'playtime_forever': 62, 'playtime_2weeks': 0}, {'item_id': '19900', 'item_name': 'Far Cry 2', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '17300', 'item_name': 'Crysis', 'playtime_forever': 46, 'playtime_2weeks': 0}, {'item_id': '17330', 'item_name': 'Crysis Warhead', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '17340', 'item_name': 'Crysis Wars', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '500', 'item_name': 'Left 4 Dead', 'playtime_forever': 5761, 'playtime_2weeks': 0}, {'item_id': '16450', 'item_name': 'F.E.A.R. 2: Project Origin', 'playtime_forever': 2846, 'playtime_2weeks': 0}, {'item_id': '17430', 'item_name': 'Need for Speed: Undercover', 'playtime_forever': 826, 'playtime_2weeks': 0}, {'item_id': '23310', 'item_name': 'The Last Remnant', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '16720', 'item_name': 'Velvet Assassin', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '6060', 'item_name': 'STAR WARS™ Battlefront™ II', 'playtime_forever': 21, 'playtime_2weeks': 0}, {'item_id': '40700', 'item_name': 'Machinarium', 'playtime_forever': 188, 'playtime_2weeks': 0}, {'item_id': '550', 'item_name': 'Left 4 Dead 2', 'playtime_forever': 11141, 'playtime_2weeks': 0}, {'item_id': '223530', 'item_name': 'Left 4 Dead 2 Beta', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '45700', 'item_name': 'Devil May Cry 4', 'playtime_forever': 58, 'playtime_2weeks': 0}, {'item_id': '7670', 'item_name': 'BioShock', 'playtime_forever': 7, 'playtime_2weeks': 0}, {'item_id': '409710', 'item_name': 'BioShock Remastered', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '24980', 'item_name': 'Mass Effect 2', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '10680', 'item_name': 'Aliens vs. Predator', 'playtime_forever': 2662, 'playtime_2weeks': 0}, {'item_id': '13600', 'item_name': 'Prince of Persia: The Sands of Time', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '33320', 'item_name': 'Prince of Persia: The Forgotten Sands', 'playtime_forever': 64, 'playtime_2weeks': 0}, {'item_id': '17410', 'item_name': "Mirror's Edge", 'playtime_forever': 108, 'playtime_2weeks': 0}, {'item_id': '205790', 'item_name': 'Dota 2 Test', 'playtime_forever': 0, 'playtime_2weeks': 0}, {'item_id': '8930', 'item_name': "Sid Meier's Civiliza ...

# %%
# Se observa el tipo de dato que contiene 'review'
df_users_items['items'][5]
# Out:
# [{'item_id': '50',
#   'item_name': 'Half-Life: Opposing Force',
#   'playtime_forever': 256,
#   'playtime_2weeks': 0},
#  {'item_id': '240',
#   'item_name': 'Counter-Strike: Source',
#   'playtime_forever': 167,
#   'playtime_2weeks': 0},
#  {'item_id': '320',
#   'item_name': 'Half-Life 2: Deathmatch',
#   'playtime_forever': 3674,
#   'playtime_2weeks': 0},
#  {'item_id': '4000',
#   'item_name': "Garry's Mod",
#   'playtime_forever': 358,
#   'playtime_2weeks': 0},
#  {'item_id': '6570',
#   'item_name': 'Onimusha 3: Demon Siege',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '220',
#   'item_name': 'Half-Life 2',
#   'playtime_forever': 1299,
#   'playtime_2weeks': 0},
#  {'item_id': '340',
#   'item_name': 'Half-Life 2: Lost Coast',
#   'playtime_forever': 29,
#   'playtime_2weeks': 0},
#  {'item_id': '360',
#   'item_name': 'Half-Life Deathmatch: Source',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '380',
#   'item_name': 'Half-Life 2: Episode One',
#   'playtime_forever': 170,
#   'playtime_2weeks': 0},
#  {'item_id': '400',
#   'item_name': 'Portal',
#   'playtime_forever': 275,
#   'playtime_2weeks': 0},
#  {'item_id': '420',
#   'item_name': 'Half-Life 2: Episode Two',
#   'playtime_forever': 544,
#   'playtime_2weeks': 0},
#  {'item_id': '12900',
#   'item_name': 'Audiosurf',
#   'playtime_forever': 95,
#   'playtime_2weeks': 0},
#  {'item_id': '13240',
#   'item_name': 'Unreal Tournament: Game of the Year Edition',
#   'playtime_forever': 110,
#   'playtime_2weeks': 0},
#  {'item_id': '13230',
#   'item_name': 'Unreal Tournament 2004',
#   'playtime_forever': 1668,
#   'playtime_2weeks': 0},
#  {'item_id': '15700',
#   'item_name': "Oddworld: Abe's Oddysee",
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '15710',
#   'item_name': "Oddworld: Abe's Exoddus",
#   'playtime_forever': 62,
#   'playtime_2weeks': 0},
#  {'item_id': '19900',
#   'item_name': 'Far Cry 2',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '17300',
#   'item_name': 'Crysis',
#   'playtime_forever': 46,
#   'playtime_2weeks': 0},
#  {'item_id': '17330',
#   'item_name': 'Crysis Warhead',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '17340',
#   'item_name': 'Crysis Wars',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '500',
#   'item_name': 'Left 4 Dead',
#   'playtime_forever': 5761,
#   'playtime_2weeks': 0},
#  {'item_id': '16450',
#   'item_name': 'F.E.A.R. 2: Project Origin',
#   'playtime_forever': 2846,
#   'playtime_2weeks': 0},
#  {'item_id': '17430',
#   'item_name': 'Need for Speed: Undercover',
#   'playtime_forever': 826,
#   'playtime_2weeks': 0},
#  {'item_id': '23310',
#   'item_name': 'The Last Remnant',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '16720',
#   'item_name': 'Velvet Assassin',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '6060',
#   'item_name': 'STAR WARS™ Battlefront™ II',
#   'playtime_forever': 21,
#   'playtime_2weeks': 0},
#  {'item_id': '40700',
#   'item_name': 'Machinarium',
#   'playtime_forever': 188,
#   'playtime_2weeks': 0},
#  {'item_id': '550',
#   'item_name': 'Left 4 Dead 2',
#   'playtime_forever': 11141,
#   'playtime_2weeks': 0},
#  {'item_id': '223530',
#   'item_name': 'Left 4 Dead 2 Beta',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '45700',
#   'item_name': 'Devil May Cry 4',
#   'playtime_forever': 58,
#   'playtime_2weeks': 0},
#  {'item_id': '7670',
#   'item_name': 'BioShock',
#   'playtime_forever': 7,
#   'playtime_2weeks': 0},
#  {'item_id': '409710',
#   'item_name': 'BioShock Remastered',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '24980',
#   'item_name': 'Mass Effect 2',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '10680',
#   'item_name': 'Aliens vs. Predator',
#   'playtime_forever': 2662,
#   'playtime_2weeks': 0},
#  {'item_id': '13600',
#   'item_name': 'Prince of Persia: The Sands of Time',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '33320',
#   'item_name': 'Prince of Persia: The Forgotten Sands',
#   'playtime_forever': 64,
#   'playtime_2weeks': 0},
#  {'item_id': '17410',
#   'item_name': "Mirror's Edge",
#   'playtime_forever': 108,
#   'playtime_2weeks': 0},
#  {'item_id': '205790',
#   'item_name': 'Dota 2 Test',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '8930',
#   'item_name': "Sid Meier's Civilization V",
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '57300',
#   'item_name': 'Amnesia: The Dark Descent',
#   'playtime_forever': 140,
#   'playtime_2weeks': 0},
#  {'item_id': '70100',
#   'item_name': 'Hacker Evolution',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '70110',
#   'item_name': 'Hacker Evolution - Untold',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '50620',
#   'item_name': 'Darksiders',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '45750',
#   'item_name': 'Lost Planet 2',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '8980',
#   'item_name': 'Borderlands',
#   'playtime_forever': 469,
#   'playtime_2weeks': 0},
#  {'item_id': '31280',
#   'item_name': 'Poker Night at the Inventory',
#   'playtime_forever': 109,
#   'playtime_2weeks': 0},
#  {'item_id': '1250',
#   'item_name': 'Killing Floor',
#   'playtime_forever': 16435,
#   'playtime_2weeks': 0},
#  {'item_id': '35420',
#   'item_name': 'Killing Floor Mod: Defence Alliance 2',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '47780',
#   'item_name': 'Dead Space 2',
#   'playtime_forever': 339,
#   'playtime_2weeks': 0},
#  {'item_id': '50300',
#   'item_name': 'Spec Ops: The Line',
#   'playtime_forever': 54,
#   'playtime_2weeks': 0},
#  {'item_id': '21100',
#   'item_name': 'F.E.A.R. 3',
#   'playtime_forever': 390,
#   'playtime_2weeks': 0},
#  {'item_id': '63200',
#   'item_name': 'Monday Night Combat',
#   'playtime_forever': 275,
#   'playtime_2weeks': 0},
#  {'item_id': '99810',
#   'item_name': 'Bulletstorm',
#   'playtime_forever': 385,
#   'playtime_2weeks': 0},
#  {'item_id': '620',
#   'item_name': 'Portal 2',
#   'playtime_forever': 1199,
#   'playtime_2weeks': 0},
#  {'item_id': '104700',
#   'item_name': 'Super Monday Night Combat',
#   'playtime_forever': 6830,
#   'playtime_2weeks': 0},
#  {'item_id': '105600',
#   'item_name': 'Terraria',
#   'playtime_forever': 883,
#   'playtime_2weeks': 0},
#  {'item_id': '20920',
#   'item_name': 'The Witcher 2: Assassins of Kings Enhanced Edition',
#   'playtime_forever': 76,
#   'playtime_2weeks': 0},
#  {'item_id': '49470',
#   'item_name': 'Magic: The Gathering — Duels of the Planeswalkers 2012',
#   'playtime_forever': 455,
#   'playtime_2weeks': 0},
#  {'item_id': '7610',
#   'item_name': 'Railroad Tycoon 3',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '50130',
#   'item_name': 'Mafia II',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '22230',
#   'item_name': 'Rock of Ages',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '32800',
#   'item_name': 'The Lord of the Rings: War in the North',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '107100',
#   'item_name': 'Bastion',
#   'playtime_forever': 213,
#   'playtime_2weeks': 0},
#  {'item_id': '28050',
#   'item_name': 'Deus Ex: Human Revolution',
#   'playtime_forever': 422,
#   'playtime_2weeks': 0},
#  {'item_id': '33420',
#   'item_name': 'Call of Juarez: The Cartel',
#   'playtime_forever': 19,
#   'playtime_2weeks': 0},
#  {'item_id': '55150',
#   'item_name': 'Warhammer 40,000 Space Marine',
#   'playtime_forever': 1411,
#   'playtime_2weeks': 0},
#  {'item_id': '91310',
#   'item_name': 'Dead Island',
#   'playtime_forever': 1151,
#   'playtime_2weeks': 0},
#  {'item_id': '43190',
#   'item_name': 'The Haunted: Hells Reach',
#   'playtime_forever': 165,
#   'playtime_2weeks': 0},
#  {'item_id': '42910',
#   'item_name': 'Magicka',
#   'playtime_forever': 20,
#   'playtime_2weeks': 0},
#  {'item_id': '111400',
#   'item_name': 'Bunch Of Heroes',
#   'playtime_forever': 6,
#   'playtime_2weeks': 0},
#  {'item_id': '3830',
#   'item_name': 'Psychonauts',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '65800',
#   'item_name': 'Dungeon Defenders',
#   'playtime_forever': 1249,
#   'playtime_2weeks': 0},
#  {'item_id': '9200',
#   'item_name': 'RAGE',
#   'playtime_forever': 68,
#   'playtime_2weeks': 0},
#  {'item_id': '55230',
#   'item_name': 'Saints Row: The Third',
#   'playtime_forever': 1031,
#   'playtime_2weeks': 0},
#  {'item_id': '107600',
#   'item_name': 'Waves',
#   'playtime_forever': 54,
#   'playtime_2weeks': 0},
#  {'item_id': '41070',
#   'item_name': 'Serious Sam 3: BFE',
#   'playtime_forever': 983,
#   'playtime_2weeks': 0},
#  {'item_id': '6120',
#   'item_name': 'Shank',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '40800',
#   'item_name': 'Super Meat Boy',
#   'playtime_forever': 95,
#   'playtime_2weeks': 0},
#  {'item_id': '63710',
#   'item_name': 'BIT.TRIP RUNNER',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '94200',
#   'item_name': 'Jamestown',
#   'playtime_forever': 30,
#   'playtime_2weeks': 0},
#  {'item_id': '99700',
#   'item_name': 'NightSky',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '2400',
#   'item_name': 'The Ship',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '2420',
#   'item_name': 'The Ship Single Player',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '2430',
#   'item_name': 'The Ship Tutorial',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '67370',
#   'item_name': 'The Darkness II',
#   'playtime_forever': 231,
#   'playtime_2weeks': 0},
#  {'item_id': '22380',
#   'item_name': 'Fallout: New Vegas',
#   'playtime_forever': 196,
#   'playtime_2weeks': 0},
#  {'item_id': '209120',
#   'item_name': 'Street Fighter X Tekken',
#   'playtime_forever': 236,
#   'playtime_2weeks': 0},
#  {'item_id': '209100',
#   'item_name': 'Resident Evil™: Operation Raccoon City',
#   'playtime_forever': 21,
#   'playtime_2weeks': 0},
#  {'item_id': '104900',
#   'item_name': 'ORION: Prelude',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '203730',
#   'item_name': 'Q.U.B.E.',
#   'playtime_forever': 67,
#   'playtime_2weeks': 0},
#  {'item_id': '239430',
#   'item_name': "Q.U.B.E: Director's Cut",
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '200260',
#   'item_name': 'Batman: Arkham City GOTY',
#   'playtime_forever': 223,
#   'playtime_2weeks': 0},
#  {'item_id': '108800',
#   'item_name': 'Crysis 2 Maximum Edition',
#   'playtime_forever': 521,
#   'playtime_2weeks': 0},
#  {'item_id': '42170',
#   'item_name': 'Krater',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '12750',
#   'item_name': 'GRID',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '210950',
#   'item_name': 'Rune Classic',
#   'playtime_forever': 105,
#   'playtime_2weeks': 0},
#  {'item_id': '214830',
#   'item_name': 'Half Minute Hero: Super Mega Neo Climax Ultimate Boy',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '57900',
#   'item_name': 'Duke Nukem Forever',
#   'playtime_forever': 482,
#   'playtime_2weeks': 0},
#  {'item_id': '98400',
#   'item_name': 'Hard Reset',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '35140',
#   'item_name': 'Batman: Arkham Asylum GOTY Edition',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '20500',
#   'item_name': 'Red Faction: Guerrilla Steam Edition',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '20530',
#   'item_name': 'Red Faction',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '20550',
#   'item_name': 'Red Faction II',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '55110',
#   'item_name': 'Red Faction: Armageddon',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '209080',
#   'item_name': 'Guns of Icarus Online',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '50650',
#   'item_name': 'Darksiders II',
#   'playtime_forever': 459,
#   'playtime_2weeks': 0},
#  {'item_id': '730',
#   'item_name': 'Counter-Strike: Global Offensive',
#   'playtime_forever': 74076,
#   'playtime_2weeks': 118},
#  {'item_id': '200510',
#   'item_name': 'XCOM: Enemy Unknown',
#   'playtime_forever': 1652,
#   'playtime_2weeks': 0},
#  {'item_id': '211260',
#   'item_name': 'They Bleed Pixels',
#   'playtime_forever': 131,
#   'playtime_2weeks': 0},
#  {'item_id': '4920',
#   'item_name': 'Natural Selection 2',
#   'playtime_forever': 404,
#   'playtime_2weeks': 0},
#  {'item_id': '212680',
#   'item_name': 'FTL: Faster Than Light',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '204360',
#   'item_name': 'Castle Crashers',
#   'playtime_forever': 169,
#   'playtime_2weeks': 0},
#  {'item_id': '49520',
#   'item_name': 'Borderlands 2',
#   'playtime_forever': 4880,
#   'playtime_2weeks': 110},
#  {'item_id': '200710',
#   'item_name': 'Torchlight II',
#   'playtime_forever': 376,
#   'playtime_2weeks': 0},
#  {'item_id': '41000',
#   'item_name': 'Serious Sam HD: The First Encounter',
#   'playtime_forever': 227,
#   'playtime_2weeks': 0},
#  {'item_id': '41050',
#   'item_name': 'Serious Sam Classic: The First Encounter',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '41060',
#   'item_name': 'Serious Sam Classic: The Second Encounter',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '111600',
#   'item_name': 'Serious Sam Double D XXL',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '200330',
#   'item_name': 'Serious Sam 3 Bonus Content',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '201480',
#   'item_name': 'Serious Sam: The Random Encounter',
#   'playtime_forever': 6,
#   'playtime_2weeks': 0},
#  {'item_id': '204340',
#   'item_name': 'Serious Sam 2',
#   'playtime_forever': 5,
#   'playtime_2weeks': 0},
#  {'item_id': '227780',
#   'item_name': 'Serious Sam Classics: Revolution',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '208200',
#   'item_name': 'DOOM 3: BFG Edition',
#   'playtime_forever': 369,
#   'playtime_2weeks': 0},
#  {'item_id': '219640',
#   'item_name': 'Chivalry: Medieval Warfare',
#   'playtime_forever': 339,
#   'playtime_2weeks': 0},
#  {'item_id': '232210',
#   'item_name': 'Patch testing for Chivalry',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '96300',
#   'item_name': 'Ravaged Zombie Apocalypse',
#   'playtime_forever': 60,
#   'playtime_2weeks': 0},
#  {'item_id': '218680',
#   'item_name': 'Scribblenauts Unlimited',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '214870',
#   'item_name': 'Painkiller Hell & Damnation',
#   'playtime_forever': 272,
#   'playtime_2weeks': 0},
#  {'item_id': '220240',
#   'item_name': 'Far Cry® 3',
#   'playtime_forever': 1227,
#   'playtime_2weeks': 0},
#  {'item_id': '219740',
#   'item_name': "Don't Starve",
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '322330',
#   'item_name': "Don't Starve Together",
#   'playtime_forever': 568,
#   'playtime_2weeks': 0},
#  {'item_id': '221640',
#   'item_name': 'Super Hexagon',
#   'playtime_forever': 1,
#   'playtime_2weeks': 0},
#  {'item_id': '2280',
#   'item_name': 'The Ultimate DOOM',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '2290',
#   'item_name': 'Final DOOM',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '2300',
#   'item_name': 'DOOM II: Hell on Earth',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '9160',
#   'item_name': 'Master Levels for DOOM II',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '4570',
#   'item_name': 'Warhammer 40,000: Dawn of War - Game of the Year Edition',
#   'playtime_forever': 4,
#   'playtime_2weeks': 0},
#  {'item_id': '226700',
#   'item_name': 'Infestation: Survivor Stories Classic',
#   'playtime_forever': 51,
#   'playtime_2weeks': 0},
#  {'item_id': '203160',
#   'item_name': 'Tomb Raider',
#   'playtime_forever': 396,
#   'playtime_2weeks': 0},
#  {'item_id': '212480',
#   'item_name': 'Sonic & All-Stars Racing Transformed',
#   'playtime_forever': 76,
#   'playtime_2weeks': 0},
#  {'item_id': '49540',
#   'item_name': 'Aliens: Colonial Marines',
#   'playtime_forever': 504,
#   'playtime_2weeks': 0},
#  {'item_id': '220440',
#   'item_name': 'DmC Devil May Cry',
#   'playtime_forever': 523,
#   'playtime_2weeks': 0},
#  {'item_id': '36620',
#   'item_name': 'Forsaken World ',
#   'playtime_forever': 6246,
#   'playtime_2weeks': 0},
#  {'item_id': '99900',
#   'item_name': 'Spiral Knights',
#   'playtime_forever': 4767,
#   'playtime_2weeks': 0},
#  {'item_id': '109600',
#   'item_name': 'Neverwinter',
#   'playtime_forever': 10,
#   'playtime_2weeks': 0},
#  {'item_id': '113400',
#   'item_name': 'APB Reloaded',
#   'playtime_forever': 6,
#   'playtime_2weeks': 0},
#  {'item_id': '207230',
#   'item_name': 'Archeblade',
#   'playtime_forever': 94,
#   'playtime_2weeks': 0},
#  {'item_id': '212160',
#   'item_name': 'Vindictus',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '218230',
#   'item_name': 'PlanetSide 2',
#   'playtime_forever': 2507,
#   'playtime_2weeks': 0},
#  {'item_id': '230410',
#   'item_name': 'Warframe',
#   'playtime_forever': 9555,
#   'playtime_2weeks': 55},
#  {'item_id': '238070',
#   'item_name': 'Shadow Warrior Classic (1997)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '209870',
#   'item_name': 'Blacklight: Retribution',
#   'playtime_forever': 242,
#   'playtime_2weeks': 0},
#  {'item_id': '223710',
#   'item_name': 'Cry of Fear',
#   'playtime_forever': 997,
#   'playtime_2weeks': 0},
#  {'item_id': '262410',
#   'item_name': 'World of Guns: Gun Disassembly',
#   'playtime_forever': 95,
#   'playtime_2weeks': 0},
#  {'item_id': '224260',
#   'item_name': 'No More Room in Hell',
#   'playtime_forever': 2858,
#   'playtime_2weeks': 0},
#  {'item_id': '21690',
#   'item_name': 'Resident Evil 5 / Biohazard 5',
#   'playtime_forever': 158,
#   'playtime_2weeks': 0},
#  {'item_id': '221040',
#   'item_name': 'Resident Evil 6 / Biohazard 6',
#   'playtime_forever': 2484,
#   'playtime_2weeks': 0},
#  {'item_id': '227680',
#   'item_name': 'StarForge',
#   'playtime_forever': 17,
#   'playtime_2weeks': 0},
#  {'item_id': '225140',
#   'item_name': 'Duke Nukem 3D: Megaton Edition',
#   'playtime_forever': 30,
#   'playtime_2weeks': 0},
#  {'item_id': '233470',
#   'item_name': 'Evoland',
#   'playtime_forever': 28,
#   'playtime_2weeks': 0},
#  {'item_id': '8870',
#   'item_name': 'BioShock Infinite',
#   'playtime_forever': 515,
#   'playtime_2weeks': 0},
#  {'item_id': '234710',
#   'item_name': 'Poker Night 2',
#   'playtime_forever': 275,
#   'playtime_2weeks': 0},
#  {'item_id': '43160',
#   'item_name': 'Metro: Last Light',
#   'playtime_forever': 1102,
#   'playtime_2weeks': 0},
#  {'item_id': '44350',
#   'item_name': 'GRID 2',
#   'playtime_forever': 18,
#   'playtime_2weeks': 0},
#  {'item_id': '72850',
#   'item_name': 'The Elder Scrolls V: Skyrim',
#   'playtime_forever': 4473,
#   'playtime_2weeks': 0},
#  {'item_id': '224760',
#   'item_name': 'FEZ',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '216250',
#   'item_name': 'Dead Island Riptide',
#   'playtime_forever': 20,
#   'playtime_2weeks': 0},
#  {'item_id': '210770',
#   'item_name': 'Sanctum 2',
#   'playtime_forever': 471,
#   'playtime_2weeks': 0},
#  {'item_id': '235250',
#   'item_name': 'Super Sanctum TD',
#   'playtime_forever': 41,
#   'playtime_2weeks': 0},
#  {'item_id': '65930',
#   'item_name': 'The Bureau: XCOM Declassified',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '204450',
#   'item_name': 'Call of Juarez Gunslinger',
#   'playtime_forever': 275,
#   'playtime_2weeks': 0},
#  {'item_id': '238210',
#   'item_name': 'System Shock 2',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '35700',
#   'item_name': 'Trine',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '35720',
#   'item_name': 'Trine 2',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '230310',
#   'item_name': 'Akaneiro: Demon Hunters',
#   'playtime_forever': 10,
#   'playtime_2weeks': 0},
#  {'item_id': '208090',
#   'item_name': 'Loadout',
#   'playtime_forever': 693,
#   'playtime_2weeks': 0},
#  {'item_id': '242760',
#   'item_name': 'The Forest',
#   'playtime_forever': 677,
#   'playtime_2weeks': 0},
#  {'item_id': '217140',
#   'item_name': 'Rise of the Triad',
#   'playtime_forever': 347,
#   'playtime_2weeks': 0},
#  {'item_id': '237110',
#   'item_name': 'Mortal Kombat Komplete Edition',
#   'playtime_forever': 29,
#   'playtime_2weeks': 0},
#  {'item_id': '214950',
#   'item_name': 'Total War: ROME II - Emperor Edition',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '208610',
#   'item_name': 'Skullgirls ∞Endless Beta∞',
#   'playtime_forever': 150,
#   'playtime_2weeks': 0},
#  {'item_id': '245170',
#   'item_name': 'Skullgirls',
#   'playtime_forever': 107,
#   'playtime_2weeks': 0},
#  {'item_id': '248530',
#   'item_name': 'Depth Hunter 2: Deep Dive',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '241720',
#   'item_name': 'Guncraft',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '218620',
#   'item_name': 'PAYDAY 2',
#   'playtime_forever': 3627,
#   'playtime_2weeks': 0},
#  {'item_id': '249650',
#   'item_name': 'Blackguards',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '242570',
#   'item_name': 'Space Hulk',
#   'playtime_forever': 12,
#   'playtime_2weeks': 0},
#  {'item_id': '225280',
#   'item_name': 'Full Mojo Rampage',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '238320',
#   'item_name': 'Outlast',
#   'playtime_forever': 417,
#   'playtime_2weeks': 0},
#  {'item_id': '250110',
#   'item_name': 'Assault Android Cactus',
#   'playtime_forever': 89,
#   'playtime_2weeks': 0},
#  {'item_id': '206420',
#   'item_name': 'Saints Row IV',
#   'playtime_forever': 869,
#   'playtime_2weeks': 0},
#  {'item_id': '4580',
#   'item_name': 'Warhammer 40,000: Dawn of War – Dark Crusade',
#   'playtime_forever': 375,
#   'playtime_2weeks': 0},
#  {'item_id': '9310',
#   'item_name': 'Warhammer 40,000: Dawn of War – Winter Assault',
#   'playtime_forever': 5,
#   'playtime_2weeks': 0},
#  {'item_id': '9450',
#   'item_name': 'Warhammer 40,000: Dawn of War – Soulstorm',
#   'playtime_forever': 220,
#   'playtime_2weeks': 0},
#  {'item_id': '15620',
#   'item_name': 'Warhammer® 40,000™: Dawn of War® II',
#   'playtime_forever': 5,
#   'playtime_2weeks': 0},
#  {'item_id': '20570',
#   'item_name': 'Warhammer® 40,000™: Dawn of War® II - Chaos Rising™',
#   'playtime_forever': 5,
#   'playtime_2weeks': 0},
#  {'item_id': '56400',
#   'item_name': 'Warhammer® 40,000™: Dawn of War® II – Retribution™',
#   'playtime_forever': 66,
#   'playtime_2weeks': 0},
#  {'item_id': '252490',
#   'item_name': 'Rust',
#   'playtime_forever': 18211,
#   'playtime_2weeks': 0},
#  {'item_id': '252630',
#   'item_name': 'Eldritch',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '252950',
#   'item_name': 'Rocket League',
#   'playtime_forever': 3642,
#   'playtime_2weeks': 4},
#  {'item_id': '233130',
#   'item_name': 'Shadow Warrior',
#   'playtime_forever': 1199,
#   'playtime_2weeks': 0},
#  {'item_id': '255520',
#   'item_name': 'Viscera Cleanup Detail: Shadow Warrior',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '217920',
#   'item_name': 'Alien Rage - Unlimited',
#   'playtime_forever': 73,
#   'playtime_2weeks': 0},
#  {'item_id': '255370',
#   'item_name': 'KickBeat Steam Edition',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '234670',
#   'item_name': 'NARUTO SHIPPUDEN: Ultimate Ninja STORM 3 Full Burst',
#   'playtime_forever': 33,
#   'playtime_2weeks': 0},
#  {'item_id': '257750',
#   'item_name': 'Bloody Trapland',
#   'playtime_forever': 10,
#   'playtime_2weeks': 0},
#  {'item_id': '238430',
#   'item_name': 'Contagion',
#   'playtime_forever': 1371,
#   'playtime_2weeks': 0},
#  {'item_id': '261570',
#   'item_name': 'Ori and the Blind Forest',
#   'playtime_forever': 130,
#   'playtime_2weeks': 0},
#  {'item_id': '242700',
#   'item_name': 'Injustice: Gods Among Us Ultimate Edition',
#   'playtime_forever': 204,
#   'playtime_2weeks': 0},
#  {'item_id': '262060',
#   'item_name': 'Darkest Dungeon',
#   'playtime_forever': 2907,
#   'playtime_2weeks': 0},
#  {'item_id': '262150',
#   'item_name': 'Vanguard Princess',
#   'playtime_forever': 7,
#   'playtime_2weeks': 0},
#  {'item_id': '281050',
#   'item_name': "Vanguard Princess Director's Cut",
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '39210',
#   'item_name': 'FINAL FANTASY XIV: A Realm Reborn',
#   'playtime_forever': 2127,
#   'playtime_2weeks': 0},
#  {'item_id': '221380',
#   'item_name': 'Age of Empires II: HD Edition',
#   'playtime_forever': 333,
#   'playtime_2weeks': 0},
#  {'item_id': '263620',
#   'item_name': 'Mitsurugi Kamui Hikae',
#   'playtime_forever': 7,
#   'playtime_2weeks': 0},
#  {'item_id': '227300',
#   'item_name': 'Euro Truck Simulator 2',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '243800',
#   'item_name': 'Gas Guzzlers Extreme',
#   'playtime_forever': 59,
#   'playtime_2weeks': 0},
#  {'item_id': '265300',
#   'item_name': 'Lords Of The Fallen',
#   'playtime_forever': 1578,
#   'playtime_2weeks': 0},
#  {'item_id': '211820',
#   'item_name': 'Starbound',
#   'playtime_forever': 120,
#   'playtime_2weeks': 0},
#  {'item_id': '367540',
#   'item_name': 'Starbound - Unstable',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '202170',
#   'item_name': 'Sleeping Dogs™',
#   'playtime_forever': 296,
#   'playtime_2weeks': 0},
#  {'item_id': '269310',
#   'item_name': 'Infectonator : Survivors',
#   'playtime_forever': 24,
#   'playtime_2weeks': 0},
#  {'item_id': '235460',
#   'item_name': 'METAL GEAR RISING: REVENGEANCE',
#   'playtime_forever': 698,
#   'playtime_2weeks': 0},
#  {'item_id': '271290',
#   'item_name': 'HAWKEN',
#   'playtime_forever': 187,
#   'playtime_2weeks': 0},
#  {'item_id': '274310',
#   'item_name': 'Always Sometimes Monsters',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '222880',
#   'item_name': 'Insurgency',
#   'playtime_forever': 95,
#   'playtime_2weeks': 0},
#  {'item_id': '226840',
#   'item_name': 'Age of Wonders III',
#   'playtime_forever': 32,
#   'playtime_2weeks': 0},
#  {'item_id': '277430',
#   'item_name': 'Halo: Spartan Assault',
#   'playtime_forever': 25,
#   'playtime_2weeks': 0},
#  {'item_id': '239160',
#   'item_name': 'Thief',
#   'playtime_forever': 116,
#   'playtime_2weeks': 0},
#  {'item_id': '282440',
#   'item_name': 'Quake Live',
#   'playtime_forever': 327,
#   'playtime_2weeks': 123},
#  {'item_id': '8880',
#   'item_name': 'Freedom Force',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '8890',
#   'item_name': 'Freedom Force vs. the 3rd Reich',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '286160',
#   'item_name': 'Tabletop Simulator',
#   'playtime_forever': 311,
#   'playtime_2weeks': 0},
#  {'item_id': '287700',
#   'item_name': 'METAL GEAR SOLID V: THE PHANTOM PAIN',
#   'playtime_forever': 235,
#   'playtime_2weeks': 0},
#  {'item_id': '274190',
#   'item_name': 'Broforce',
#   'playtime_forever': 182,
#   'playtime_2weeks': 0},
#  {'item_id': '290080',
#   'item_name': 'Life is Feudal: Your Own',
#   'playtime_forever': 61,
#   'playtime_2weeks': 0},
#  {'item_id': '292030',
#   'item_name': 'The Witcher 3: Wild Hunt',
#   'playtime_forever': 878,
#   'playtime_2weeks': 0},
#  {'item_id': '261510',
#   'item_name': 'Tesla Effect',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '201810',
#   'item_name': 'Wolfenstein: The New Order',
#   'playtime_forever': 1145,
#   'playtime_2weeks': 0},
#  {'item_id': '294810',
#   'item_name': 'BlazBlue: Continuum Shift Extend',
#   'playtime_forever': 7,
#   'playtime_2weeks': 0},
#  {'item_id': '222900',
#   'item_name': 'Dead Island: Epidemic',
#   'playtime_forever': 2,
#   'playtime_2weeks': 0},
#  {'item_id': '35450',
#   'item_name': 'Rising Storm/Red Orchestra 2 Multiplayer',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '236830',
#   'item_name': 'Red Orchestra 2: Heroes of Stalingrad - Single Player',
#   'playtime_forever': 20,
#   'playtime_2weeks': 0},
#  {'item_id': '298110',
#   'item_name': 'Far Cry 4',
#   'playtime_forever': 575,
#   'playtime_2weeks': 0},
#  {'item_id': '292120',
#   'item_name': 'FINAL FANTASY XIII',
#   'playtime_forever': 364,
#   'playtime_2weeks': 0},
#  {'item_id': '286690',
#   'item_name': 'Metro 2033 Redux',
#   'playtime_forever': 61,
#   'playtime_2weeks': 0},
#  {'item_id': '287390',
#   'item_name': 'Metro: Last Light Redux',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '301520',
#   'item_name': 'Robocraft',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '301640',
#   'item_name': 'Zombie Army Trilogy',
#   'playtime_forever': 249,
#   'playtime_2weeks': 0},
#  {'item_id': '244160',
#   'item_name': 'Homeworld Remastered Collection',
#   'playtime_forever': 2,
#   'playtime_2weeks': 0},
#  {'item_id': '304930',
#   'item_name': 'Unturned',
#   'playtime_forever': 252,
#   'playtime_2weeks': 0},
#  {'item_id': '306410',
#   'item_name': 'Crystals of Time',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '224600',
#   'item_name': 'Defiance',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '306830',
#   'item_name': 'Zombies Monsters Robots',
#   'playtime_forever': 236,
#   'playtime_2weeks': 0},
#  {'item_id': '227700',
#   'item_name': 'Firefall',
#   'playtime_forever': 12,
#   'playtime_2weeks': 0},
#  {'item_id': '311690',
#   'item_name': 'Enter the Gungeon',
#   'playtime_forever': 1078,
#   'playtime_2weeks': 0},
#  {'item_id': '291480',
#   'item_name': 'Warface',
#   'playtime_forever': 17,
#   'playtime_2weeks': 0},
#  {'item_id': '244630',
#   'item_name': 'NEOTOKYO°',
#   'playtime_forever': 6,
#   'playtime_2weeks': 0},
#  {'item_id': '227940',
#   'item_name': 'Heroes & Generals',
#   'playtime_forever': 7,
#   'playtime_2weeks': 0},
#  {'item_id': '265590',
#   'item_name': 'The Red Solstice',
#   'playtime_forever': 4,
#   'playtime_2weeks': 0},
#  {'item_id': '313340',
#   'item_name': 'Mountain',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '317620',
#   'item_name': 'Space Hulk Ascension',
#   'playtime_forever': 6,
#   'playtime_2weeks': 0},
#  {'item_id': '261640',
#   'item_name': 'Borderlands: The Pre-Sequel',
#   'playtime_forever': 3216,
#   'playtime_2weeks': 0},
#  {'item_id': '319280',
#   'item_name': 'Yatagarasu Attack on Cataclysm',
#   'playtime_forever': 8,
#   'playtime_2weeks': 2},
#  {'item_id': '320240',
#   'item_name': 'We Happy Few',
#   'playtime_forever': 207,
#   'playtime_2weeks': 0},
#  {'item_id': '274170',
#   'item_name': 'Hotline Miami 2: Wrong Number',
#   'playtime_forever': 68,
#   'playtime_2weeks': 0},
#  {'item_id': '322910',
#   'item_name': 'Warhammer 40,000: Regicide',
#   'playtime_forever': 134,
#   'playtime_2weeks': 7},
#  {'item_id': '323370',
#   'item_name': 'TERA',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '209650',
#   'item_name': 'Call of Duty: Advanced Warfare',
#   'playtime_forever': 429,
#   'playtime_2weeks': 0},
#  {'item_id': '209660',
#   'item_name': 'Call of Duty: Advanced Warfare - Multiplayer',
#   'playtime_forever': 143,
#   'playtime_2weeks': 0},
#  {'item_id': '214490',
#   'item_name': 'Alien: Isolation',
#   'playtime_forever': 703,
#   'playtime_2weeks': 0},
#  {'item_id': '241930',
#   'item_name': 'Middle-earth: Shadow of Mordor',
#   'playtime_forever': 852,
#   'playtime_2weeks': 0},
#  {'item_id': '239140',
#   'item_name': 'Dying Light',
#   'playtime_forever': 2491,
#   'playtime_2weeks': 12},
#  {'item_id': '328070',
#   'item_name': 'Reflex',
#   'playtime_forever': 92,
#   'playtime_2weeks': 0},
#  {'item_id': '24240',
#   'item_name': 'PAYDAY: The Heist',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '268050',
#   'item_name': 'The Evil Within',
#   'playtime_forever': 1008,
#   'playtime_2weeks': 0},
#  {'item_id': '323470',
#   'item_name': 'DRAGON BALL XENOVERSE',
#   'playtime_forever': 643,
#   'playtime_2weeks': 0},
#  {'item_id': '332970',
#   'item_name': 'Storm United',
#   'playtime_forever': 16,
#   'playtime_2weeks': 0},
#  {'item_id': '337630',
#   'item_name': 'Bermuda',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '273350',
#   'item_name': 'Evolve Stage 2',
#   'playtime_forever': 1345,
#   'playtime_2weeks': 0},
#  {'item_id': '242680',
#   'item_name': 'Nuclear Throne',
#   'playtime_forever': 62,
#   'playtime_2weeks': 0},
#  {'item_id': '341980',
#   'item_name': 'Dispatcher',
#   'playtime_forever': 3,
#   'playtime_2weeks': 0},
#  {'item_id': '342200',
#   'item_name': 'MechWarrior Online',
#   'playtime_forever': 8412,
#   'playtime_2weeks': 0},
#  {'item_id': '314660',
#   'item_name': "Oddworld: New 'n' Tasty",
#   'playtime_forever': 21,
#   'playtime_2weeks': 21},
#  {'item_id': '271590',
#   'item_name': 'Grand Theft Auto V',
#   'playtime_forever': 9119,
#   'playtime_2weeks': 0},
#  {'item_id': '346110',
#   'item_name': 'ARK: Survival Evolved',
#   'playtime_forever': 5820,
#   'playtime_2weeks': 0},
#  {'item_id': '407530',
#   'item_name': 'ARK: Survival Of The Fittest',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '307780',
#   'item_name': 'Mortal Kombat X',
#   'playtime_forever': 357,
#   'playtime_2weeks': 0},
#  {'item_id': '347560',
#   'item_name': 'Terra Incognita ~ Chapter One: The Descendant',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '107410',
#   'item_name': 'Arma 3',
#   'playtime_forever': 67,
#   'playtime_2weeks': 0},
#  {'item_id': '339280',
#   'item_name': 'Strife',
#   'playtime_forever': 5,
#   'playtime_2weeks': 0},
#  {'item_id': '351570',
#   'item_name': 'Killing Floor: Uncovered',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '355840',
#   'item_name': 'Survarium',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '333930',
#   'item_name': 'Dirty Bomb',
#   'playtime_forever': 3123,
#   'playtime_2weeks': 0},
#  {'item_id': '235540',
#   'item_name': 'Warhammer: End Times - Vermintide',
#   'playtime_forever': 2332,
#   'playtime_2weeks': 0},
#  {'item_id': '306130',
#   'item_name': 'The Elder Scrolls Online: Tamriel Unlimited',
#   'playtime_forever': 1329,
#   'playtime_2weeks': 0},
#  {'item_id': '359320',
#   'item_name': 'Elite Dangerous',
#   'playtime_forever': 5165,
#   'playtime_2weeks': 0},
#  {'item_id': '232090',
#   'item_name': 'Killing Floor 2',
#   'playtime_forever': 11462,
#   'playtime_2weeks': 303},
#  {'item_id': '232150',
#   'item_name': 'Killing Floor 2 - SDK',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '361700',
#   'item_name': 'Mortal Kombat: Legacy',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '361710',
#   'item_name': 'Mortal Kombat: Legacy: Jax, Sonya and Kano (Part 2)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '361720',
#   'item_name': 'Mortal Kombat: Legacy: Johnny Cage',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '361730',
#   'item_name': 'Mortal Kombat: Legacy: Kitana & Mileena (Part 1)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '361740',
#   'item_name': 'Mortal Kombat: Legacy: Kitana & Mileena (Part 2)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '361750',
#   'item_name': 'Mortal Kombat: Legacy: Raiden',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '361760',
#   'item_name': 'Mortal Kombat: Legacy: Scorpion and Sub-Zero (Part 1)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '361770',
#   'item_name': 'Mortal Kombat: Legacy: Scorpion and Sub-Zero (Part 2)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '361780',
#   'item_name': 'Mortal Kombat: Legacy: Cyrax & Sektor',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '495460',
#   'item_name': 'Mortal Kombat: Legacy: Jax, Sonya and Kano (Part 1)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '346680',
#   'item_name': 'Black Mesa Dedicated Server',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '362890',
#   'item_name': 'Black Mesa',
#   'playtime_forever': 509,
#   'playtime_2weeks': 0},
#  {'item_id': '365590',
#   'item_name': "Tom Clancy's The Division",
#   'playtime_forever': 2634,
#   'playtime_2weeks': 0},
#  {'item_id': '365720',
#   'item_name': 'Skyrim Script Extender (SKSE)',
#   'playtime_forever': 1,
#   'playtime_2weeks': 0},
#  {'item_id': '367120',
#   'item_name': 'Seduce Me the Otome',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '367500',
#   'item_name': "Dragon's Dogma: Dark Arisen",
#   'playtime_forever': 30,
#   'playtime_2weeks': 0},
#  {'item_id': '369990',
#   'item_name': 'Gremlins, Inc.',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '370240',
#   'item_name': 'NBA 2K16',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '372000',
#   'item_name': 'Tree of Savior (English Ver.)',
#   'playtime_forever': 181,
#   'playtime_2weeks': 0},
#  {'item_id': '373680',
#   'item_name': 'Aion',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '374320',
#   'item_name': 'DARK SOULS III',
#   'playtime_forever': 5491,
#   'playtime_2weeks': 1219},
#  {'item_id': '375230',
#   'item_name': 'Warhammer 40,000: Eternal Crusade',
#   'playtime_forever': 53,
#   'playtime_2weeks': 0},
#  {'item_id': '377160',
#   'item_name': 'Fallout 4',
#   'playtime_forever': 2040,
#   'playtime_2weeks': 0},
#  {'item_id': '377310',
#   'item_name': 'The Tower Of Elements',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '247080',
#   'item_name': 'Crypt of the NecroDancer',
#   'playtime_forever': 52,
#   'playtime_2weeks': 52},
#  {'item_id': '314680',
#   'item_name': 'Crypt of the Necrodancer Soundtrack',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '366080',
#   'item_name': 'Crypt of the NecroDancer Extended Soundtrack',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '208650',
#   'item_name': 'Batman™: Arkham Knight',
#   'playtime_forever': 958,
#   'playtime_2weeks': 0},
#  {'item_id': '209000',
#   'item_name': 'Batman™: Arkham Origins',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '267490',
#   'item_name': 'Batman™: Arkham Origins Blackgate - Deluxe Edition',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '383080',
#   'item_name': 'Sakura Clicker',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '383330',
#   'item_name': 'Star Chronicles: Delta Quadrant',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '383580',
#   'item_name': 'Flesh Eaters',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '386360',
#   'item_name': 'SMITE',
#   'playtime_forever': 3869,
#   'playtime_2weeks': 0},
#  {'item_id': '391540',
#   'item_name': 'Undertale',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '234140',
#   'item_name': 'Mad Max',
#   'playtime_forever': 1527,
#   'playtime_2weeks': 0},
#  {'item_id': '393420',
#   'item_name': 'Hurtworld',
#   'playtime_forever': 97,
#   'playtime_2weeks': 0},
#  {'item_id': '445900',
#   'item_name': 'Hurtworld SDK',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '396900',
#   'item_name': 'GRIP',
#   'playtime_forever': 126,
#   'playtime_2weeks': 0},
#  {'item_id': '337000',
#   'item_name': 'Deus Ex: Mankind Divided™',
#   'playtime_forever': 293,
#   'playtime_2weeks': 0},
#  {'item_id': '399430',
#   'item_name': 'Tinboy',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '311210',
#   'item_name': 'Call of Duty: Black Ops III',
#   'playtime_forever': 830,
#   'playtime_2weeks': 0},
#  {'item_id': '299360',
#   'item_name': 'Block N Load',
#   'playtime_forever': 10,
#   'playtime_2weeks': 0},
#  {'item_id': '319510',
#   'item_name': "Five Nights at Freddy's",
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '332800',
#   'item_name': "Five Nights at Freddy's 2",
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '354140',
#   'item_name': "Five Nights at Freddy's 3",
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '388090',
#   'item_name': "Five Nights at Freddy's 4",
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '407840',
#   'item_name': 'ORION',
#   'playtime_forever': 25,
#   'playtime_2weeks': 0},
#  {'item_id': '394510',
#   'item_name': 'HELLDIVERS™',
#   'playtime_forever': 101,
#   'playtime_2weeks': 0},
#  {'item_id': '236110',
#   'item_name': 'Dungeon Defenders II',
#   'playtime_forever': 143,
#   'playtime_2weeks': 0},
#  {'item_id': '364360',
#   'item_name': 'Total War: WARHAMMER',
#   'playtime_forever': 69,
#   'playtime_2weeks': 0},
#  {'item_id': '369200',
#   'item_name': 'Ghost in the Shell Stand Alone Complex First Assault Online',
#   'playtime_forever': 42,
#   'playtime_2weeks': 0},
#  {'item_id': '272890',
#   'item_name': 'Vertiginous Golf',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '230230',
#   'item_name': 'Divinity: Original Sin (Classic)',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '373420',
#   'item_name': 'Divinity: Original Sin Enhanced Edition',
#   'playtime_forever': 1631,
#   'playtime_2weeks': 0},
#  {'item_id': '231430',
#   'item_name': 'Company of Heroes 2',
#   'playtime_forever': 12,
#   'playtime_2weeks': 12},
#  {'item_id': '359550',
#   'item_name': "Tom Clancy's Rainbow Six Siege",
#   'playtime_forever': 152,
#   'playtime_2weeks': 4},
#  {'item_id': '435150',
#   'item_name': 'Divinity: Original Sin 2',
#   'playtime_forever': 266,
#   'playtime_2weeks': 266},
#  {'item_id': '290790',
#   'item_name': 'Grey Goo',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '268500',
#   'item_name': 'XCOM 2',
#   'playtime_forever': 3269,
#   'playtime_2weeks': 0},
#  {'item_id': '34270',
#   'item_name': 'SEGA Mega Drive & Genesis Classics',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '205230',
#   'item_name': 'Hell Yeah!',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '205950',
#   'item_name': 'Jet Set Radio',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '444090',
#   'item_name': 'Paladins',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '295110',
#   'item_name': 'H1Z1: Just Survive',
#   'playtime_forever': 72,
#   'playtime_2weeks': 0},
#  {'item_id': '362300',
#   'item_name': 'H1Z1: Just Survive Test Server',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '394230',
#   'item_name': 'Battleborn',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '381210',
#   'item_name': 'Dead by Daylight',
#   'playtime_forever': 677,
#   'playtime_2weeks': 0},
#  {'item_id': '379720',
#   'item_name': 'DOOM',
#   'playtime_forever': 2220,
#   'playtime_2weeks': 0},
#  {'item_id': '475150',
#   'item_name': 'Titan Quest Anniversary Edition',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '48000',
#   'item_name': 'LIMBO',
#   'playtime_forever': 0,
#   'playtime_2weeks': 0},
#  {'item_id': '363680',
#   'item_name': 'Battlefleet Gothic: Armada',
#   'playtime_forever': 43,
#   'playtime_2weeks': 43}]

# %% [markdown]
# ### Alcance preliminar del diccionario de datos de "User reviews"
#
# **Descripción:**
#
# Este conjunto de datos contiene información sobre videojuegos. Tras la limpieza de filas no se evidencia valores tipo NaN, el conjunto final consta de 88309 filas y 5 columnas. A continuación, se detalla la descripción de cada columna:
#
# **Columnas:**
#
# * **user_id**: contiene un identificador único del usuario.
# * **items_count**: contiene un número entero que indica la cantidad de juegos que ha consumido el usuario.
# * **steam_id**: es un número único para la plataforma.
# * **user_url**: es la url del perfil del usuario
# * **items**: contiene una lista de uno o mas diccionarios de los items que consume cada usuario. Cada diccionario tiene las siguientes claves:
#     * **item_id**: es el identificados del item, es decir, del juego.
#     * **item_name**: es el nombre del contenido que consume, es decir, del juego.
#     * **playtime_forever**: es el tiempo acumulado que un usuario jugó a un juego.
#     * **playtime_2weeks**: es el tiempo acumulado que un usuario jugó a un juego en las últimas dos semanas.
#
# **Notas:**
#
# * Las columnas `items` contienen listas de diccionarios.

# %% [markdown]
# ### 3.2.3.- Eliminación de datos duplicados

# %% [markdown]
# Se analizan si hay duplicados teniendo en cuenta la columna de `items`, al ser una columna anidada, esta debe ser normalizada primero.

# %%
elementos_duplicados = FP.verifica_duplicados_por_columna(df_users_items, 'user_id')
elementos_duplicados
# Out:
#                      user_id  items_count           steam_id  \
# 11000               05041129           35  76561198167088451
# 29193               05041129           35  76561198167088451
# 37062         10outof10matee           56  76561198050688208
# 37061         10outof10matee           56  76561198050688208
# 6167   111222333444555666888           52  76561198082607692
# ...                      ...          ...                ...
# 4625       youseeitnowgetout            5  76561198087136132
# 3473                 zandado          107  76561198057890701
# 34176                zandado          107  76561198057890701
# 12417              zeroblade          306  76561197970272666
# 31866              zeroblade          306  76561197970272666
#
#                                                 user_url  \
# 11000              http://steamcommunity.com/id/05041129
# 29193              http://steamcommunity.com/id/05041129
# 37062        http://steamcommunity.com/id/10outof10matee
# 37061        http://steamcommunity.com/id/10outof10matee
# 6167   http://steamcommunity.com/id/11122233344455566...
# ...                                                  ...
# 4625      http://steamcommunity.com/id/youseeitnowgetout
# 3473                http://steamcommunity.com/id/zandado
# 34176               http://steamcommunity.com/id/zandado
# 12417             http://steamcommunity.com/id/zeroblade
# 31866             http://steamcommunity.com/id/zeroblade
#
#                                                    items
# 11000  [{'item_id': '4000', 'item_name': 'Garry's Mod...
# 29193  [{'item_id': '4000', 'item_name': 'Garry's Mod...
# 37062  [{'item_id': '220', 'item_name': 'Half-Life 2'...
# 37061  [{'item_id': '220', 'item_name': 'Half-Life 2'...
# 6167   [{'item_id': '240', 'item_name': 'Counter-Stri...
# ...                                                  ...
# 4625   [{'item_id': '230410', 'item_name': 'Warframe'...
# 3473   [{'item_id': '20', 'item_name': 'Team Fortress...
# 34176  [{'item_id': '20', 'item_name': 'Team Fortress...
# 12417  [{'item_id': '18110', 'item_name': 'Shattered ...
# 31866  [{'item_id': '10', 'item_name': 'Counter-Strik...
#
# [1357 rows x 5 columns]

# %% [markdown]
# Identificación de Items Duplicados:
#
# Se han detectado 1357 items duplicados en el conjunto de datos, sin embargo:
#
# * **Primero:** Se revisan si los review dentro de los datos anidados de 'items' la información
# * **Segundo:** Corroborar si se encuentra duplicada o si solo se duplica el 'user_id' porque hay mas de un comentario realizado por ese usuario.

# %% [markdown]
# Se debe realizar una verificación aparte para la columna 'items', donde se debe normalizar y analizar los elementos del diccionario

# %% [markdown]
# ### 3.2.4.- Datos incorrectos o irrelevantes

# %% [markdown]
# * En una primera instancia, hasta el momento no hay columnas por eliminar.
# * La columna items al ser una columna anidada, podría contener información valiosa como también irrelevante, por lo que requiere un análisis más profundo que se abordará en el siguiente punto.

# %% [markdown]
# ### 3.2.5.- Datos categóricos

# %% [markdown]
# #### 3.2.5.1 Columna 'items'

# %% [markdown]
# La columna 'items' se presenta anidada, siendo una lista con uno o mas diccionarios como elementos. Se busca generar una columna por cada diccionario para posteriormente hacer un registro por cada diccionario.

# %%
# se normaliza la columna 'items'
df_norm_items = pd.json_normalize(rows, record_path=['items'], meta=['steam_id','items_count','user_id', 'user_url'] )
df_norm_items
# Out:
#         item_id                      item_name  playtime_forever  \
# 0            10                 Counter-Strike                 6
# 1            20          Team Fortress Classic                 0
# 2            30                  Day of Defeat                 7
# 3            40             Deathmatch Classic                 0
# 4            50      Half-Life: Opposing Force                 0
# ...         ...                            ...               ...
# 5153204  346330                   BrainBread 2                 0
# 5153205  373330                    All Is Dust                 0
# 5153206  388490  One Way To Die: Steam Edition                 3
# 5153207  521570          You Have 10 Seconds 2                 4
# 5153208  519140                     Minds Eyes                 3
#
#          playtime_2weeks           steam_id items_count            user_id  \
# 0                      0  76561197970982479         277  76561197970982479
# 1                      0  76561197970982479         277  76561197970982479
# 2                      0  76561197970982479         277  76561197970982479
# 3                      0  76561197970982479         277  76561197970982479
# 4                      0  76561197970982479         277  76561197970982479
# ...                  ...                ...         ...                ...
# 5153204                0  76561198329548331           7  76561198329548331
# 5153205                0  76561198329548331           7  76561198329548331
# 5153206                3  76561198329548331           7  76561198329548331
# 5153207                4  76561198329548331           7  76561198329548331
# 5153208                3  76561198329548331           7  76561198329548331
#
#                                                   user_url
# 0        http://steamcommunity.com/profiles/76561197970...
# 1        http://steamcommunity.com/profiles/76561197970...
# 2        http://steamcommunity.com/profiles/76561197970...
# 3        http://steamcommunity.com/profiles/76561197970...
# 4        http://steamcommunity.com/profiles/76561197970...
# ...                                                    ...
# 5153204  http://steamcommunity.com/profiles/76561198329...
# 5153205  http://steamcommunity.com/profiles/76561198329...
# 5153206  http://steamcommunity.com/profiles/76561198329...
# 5153207  http://steamcommunity.com/profiles/76561198329...
# 5153208  http://steamcommunity.com/profiles/76561198329...
#
# [5153209 rows x 8 columns]

# %% [markdown]
# Verificamos la cantidad de datos nulos

# %%
# Verificamos la cantidad de datos nulos
FP.tabla_tipo_datos(df_norm_items)
# Out:
#        nombre_campo       tipo_datos  no_nulos_%  nulos_%  nulos
# 0           item_id  [<class 'str'>]       100.0      0.0      0
# 1         item_name  [<class 'str'>]       100.0      0.0      0
# 2  playtime_forever  [<class 'int'>]       100.0      0.0      0
# 3   playtime_2weeks  [<class 'int'>]       100.0      0.0      0
# 4          steam_id  [<class 'str'>]       100.0      0.0      0
# 5       items_count  [<class 'int'>]       100.0      0.0      0
# 6           user_id  [<class 'str'>]       100.0      0.0      0
# 7          user_url  [<class 'str'>]       100.0      0.0      0

# %% [markdown]
# Verificamos la existencia de duplicados

# %%
# Devuelve los duplicados
elementos_duplicados = df_norm_items.loc[df_norm_items.duplicated()]
elementos_duplicados
# Out:
#         item_id                         item_name  playtime_forever  \
# 164294       20             Team Fortress Classic                 5
# 164295       50         Half-Life: Opposing Force                 0
# 164296       70                         Half-Life                 0
# 164297      130             Half-Life: Blue Shift                 0
# 164298      220                       Half-Life 2               198
# ...         ...                               ...               ...
# 4898223  213670  South Park™: The Stick of Truth™               725
# 4898224  221910               The Stanley Parable                53
# 4898225  261030      The Walking Dead: Season Two               253
# 4898226  273110     Counter-Strike Nexon: Zombies                 0
# 4898227     730  Counter-Strike: Global Offensive                 0
#
#          playtime_2weeks           steam_id items_count            user_id  \
# 164294                 0  76561198084006094         109             Nikiad
# 164295                 0  76561198084006094         109             Nikiad
# 164296                 0  76561198084006094         109             Nikiad
# 164297                 0  76561198084006094         109             Nikiad
# 164298                 0  76561198084006094         109             Nikiad
# ...                  ...                ...         ...                ...
# 4898223                0  76561198080057659          39  76561198080057659
# 4898224                0  76561198080057659          39  76561198080057659
# 4898225                0  76561198080057659          39  76561198080057659
# 4898226                0  76561198080057659          39  76561198080057659
# 4898227                0  76561198080057659          39  76561198080057659
#
#                                                   user_url
# 164294                 http://steamcommunity.com/id/Nikiad
# 164295                 http://steamcommunity.com/id/Nikiad
# 164296                 http://steamcommunity.com/id/Nikiad
# 164297                 http://steamcommunity.com/id/Nikiad
# 164298                 http://steamcommunity.com/id/Nikiad
# ...                                                    ...
# 4898223  http://steamcommunity.com/profiles/76561198080...
# 4898224  http://steamcommunity.com/profiles/76561198080...
# 4898225  http://steamcommunity.com/profiles/76561198080...
# 4898226  http://steamcommunity.com/profiles/76561198080...
# 4898227  http://steamcommunity.com/profiles/76561198080...
#
# [59104 rows x 8 columns]

# %% [markdown]
# Se observan 59104 duplicados, por lo que se decide borrarlos. **Manteniendo el primer elemento de cada grupo de duplicados**

# %%
df_norm_items = df_norm_items.drop_duplicates(keep='first')
df_norm_items
# Out:
#         item_id                      item_name  playtime_forever  \
# 0            10                 Counter-Strike                 6
# 1            20          Team Fortress Classic                 0
# 2            30                  Day of Defeat                 7
# 3            40             Deathmatch Classic                 0
# 4            50      Half-Life: Opposing Force                 0
# ...         ...                            ...               ...
# 5153204  346330                   BrainBread 2                 0
# 5153205  373330                    All Is Dust                 0
# 5153206  388490  One Way To Die: Steam Edition                 3
# 5153207  521570          You Have 10 Seconds 2                 4
# 5153208  519140                     Minds Eyes                 3
#
#          playtime_2weeks           steam_id items_count            user_id  \
# 0                      0  76561197970982479         277  76561197970982479
# 1                      0  76561197970982479         277  76561197970982479
# 2                      0  76561197970982479         277  76561197970982479
# 3                      0  76561197970982479         277  76561197970982479
# 4                      0  76561197970982479         277  76561197970982479
# ...                  ...                ...         ...                ...
# 5153204                0  76561198329548331           7  76561198329548331
# 5153205                0  76561198329548331           7  76561198329548331
# 5153206                3  76561198329548331           7  76561198329548331
# 5153207                4  76561198329548331           7  76561198329548331
# 5153208                3  76561198329548331           7  76561198329548331
#
#                                                   user_url
# 0        http://steamcommunity.com/profiles/76561197970...
# 1        http://steamcommunity.com/profiles/76561197970...
# 2        http://steamcommunity.com/profiles/76561197970...
# 3        http://steamcommunity.com/profiles/76561197970...
# 4        http://steamcommunity.com/profiles/76561197970...
# ...                                                    ...
# 5153204  http://steamcommunity.com/profiles/76561198329...
# 5153205  http://steamcommunity.com/profiles/76561198329...
# 5153206  http://steamcommunity.com/profiles/76561198329...
# 5153207  http://steamcommunity.com/profiles/76561198329...
# 5153208  http://steamcommunity.com/profiles/76561198329...
#
# [5094105 rows x 8 columns]

# %% [markdown]
# En esta transformación, se puede ver que la columna 'playtime_2weeks' presenta redundancia en la información don la columna 'playtime_forever', por lo que se decide eliminar.

# %%
# Se eliminan las columnas 'playtime_2weeks'
df_norm_items = df_norm_items.drop(columns=['playtime_2weeks'])
df_norm_items.columns
# Out:
# Index(['item_id', 'item_name', 'playtime_forever', 'steam_id', 'items_count',
#        'user_id', 'user_url'],
#       dtype='object')

# %% [markdown]
# **Se confirma la limpieza exitosa del dataset**

# %% [markdown]
# ### **<span style="color: #f7b538;">**3.3.- Carga de datos**</span>**

# %% [markdown]
# #### 3.3.1 Generación del archivo limpio

# %% [markdown]
# Se guarda el dataframe transformado como `user_items_limpio`

# %%
nombre_archivo_limpio = 'Datasets\df_user_items_limpio.csv'
df_norm_items.to_csv(nombre_archivo_limpio, index=False, encoding='utf-8')
print(f'Se guardó el archivo {nombre_archivo_limpio}')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_28788\3999126796.py:1: SyntaxWarning: invalid escape sequence '\d'
#   nombre_archivo_limpio = 'Datasets\df_user_items_limpio.csv'
# Se guardó el archivo Datasets\df_user_items_limpio.csv
